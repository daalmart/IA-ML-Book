# %%
# !pip install jupyter-tikz

# %load_ext jupyter_tikz

# %%
# %%tikz
#  \begin{tikzpicture}[
#  node distance=1.5cm and 1.5cm,
#  every node/.style={font=\sffamily},
#  state/.style={circle, draw, fill=blue!20, minimum size=0.7cm},
#  arrow/.style={
#         %-{Stealth[length=3mm]},
#         thick,
#         draw=blue!60!black
#     },
#     label/.style={
#         font=\small\itshape,
#         %fill=white,
#         inner sep=4pt,
#         sloped
#     }
#     ]
#             \node [state, fill=red!20](A) at (0, 0) {A};
#             \node [state] (B) at (-1.5, -1.5) {B};
#             \node [state](C) at (1.5, -1.5) {C};
#             \node [state, fill=green!20] (D) at (-2.5, -3) {D};
#             \node [state](E) at (-0.5, -3) {E};
#             \node [state](F) at (2.5, -3) {F};
#
#             \draw [arrow] (A)  -- node[label, above] {a} (B);
#             \draw [arrow] (A)  -- node[label, below] {\textcolor{red}{a'}} (B);
#
#             \draw [arrow] (A) -- node[label, above] {b} (C);
#             \draw [arrow] (A)  -- node[label, below] {\textcolor{red}{b'}} (C);
#
#             \draw [arrow] (B) -- node[label, above] {c} (D);
#             \draw [arrow] (B)  -- node[label, below] {\textcolor{red}{c'}} (D);
#
#             \draw [arrow] (B) -- node[label, above] {d} (E);
#             \draw [arrow] (B)  -- node[label, below] {\textcolor{red}{d'}} (E);
#
#             \draw [arrow] (C) -- node[label, above] {e} (F);
#             \draw [arrow] (C)  -- node[label, below] {\textcolor{red}{e'}} (F);
#         \end{tikzpicture}
